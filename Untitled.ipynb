# %% [markdown]
# Exploration de la donnée

# %%
import pandas as pd

# %%
df = pd.read_csv('dataproject.txt', sep=";", decimal=',', encoding='UTF-8')

# %%
df.head(10)
# Out:
#                       ZIBZIN  IDAvisAutorisAtionCheque  MontAnt  \
# 0  A034010041908012010710730                  71051532    40.17
# 1  A035010041908006493331734                  71051533    20.00
# 2  A013010003908005150136747                  71051534    35.00
# 3  A013010041908025639221029                  71051536    20.00
# 4  A013010003908005556100283                  71051538    20.00
# 5  A007010278908891620264901                  71051539    35.09
# 6  A056010003908116850002378                  71051541    60.00
# 7  A034013506908085106167163                  71051542   120.00
# 8  A056015589908090385895930                  71051544    59.25
# 9  A056015589908093500453310                  71051548    17.00
#
#        DAteTrAnsAction  CodeDecision  VerifiAnceCPT1  VerifiAnceCPT2  \
# 0  2016-03-21 07:47:38             0               1               1
# 1  2016-03-21 08:04:57             0               0               0
# ...

# %%
df.shape
# Out:
# (2231369, 23)

# %%
df.iloc[:,9:].describe(include='all')
# Out:
#          ScoringFP1    ScoringFP2    ScoringFP3  TAuxImpNb_RB  TAuxImpNB_CPM  \
# count  2.231369e+06  2.231369e+06  2.231369e+06  2.231369e+06   2.231369e+06
# mean   3.100542e+00  6.882686e-01  1.769416e-01  3.286594e+01   3.256122e+01
# std    3.047480e+01  9.336748e+00  5.662696e-01  9.774278e+01   3.475789e+01
# min    0.000000e+00 -4.969986e+01  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    5.874265e-03 -2.869431e+00  1.179973e-03  0.000000e+00   1.390821e+01
# 50%    1.543502e-02  0.000000e+00  2.131271e-03  1.547988e+01   2.526529e+01
# 75%    1.370299e-01  5.289664e+00  1.533859e-02  3.460208e+01   3.927492e+01
# max    1.680000e+04  4.702998e+01  1.839140e+01  1.000000e+04   7.142857e+02
#
#        EcArtNumCheq  NbrMAgAsin3J   DiffDAteTr1   DiffDAteTr2   DiffDAteTr3  \
# count  2.231369e+06  2.231369e+06  2.231369e+06  2.231369e+06  2.231369e+06
# mean   6.724334e+03  1.034200e+00  3.947808e+00  4.234163e+00  4.266234e+00
# ...

# %%
df.dtypes
# Out:
# ZIBZIN                       object
# IDAvisAutorisAtionCheque      int64
# MontAnt                     float64
# DAteTrAnsAction              object
# CodeDecision                  int64
# VerifiAnceCPT1                int64
# VerifiAnceCPT2                int64
# VerifiAnceCPT3                int64
# D2CB                          int64
# ScoringFP1                  float64
# ScoringFP2                  float64
# ScoringFP3                  float64
# TAuxImpNb_RB                float64
# TAuxImpNB_CPM               float64
# EcArtNumCheq                  int64
# NbrMAgAsin3J                  int64
# DiffDAteTr1                 float64
# DiffDAteTr2                 float64
# DiffDAteTr3                 float64
# CA3TRetMtt                  float64
# CA3TR                       float64
# Heure                         int64
# FlAgImpAye                    int64
# dtype: object

# %%
impaye = df[df['FlAgImpAye'] == 1]
impaye.shape
# Out:
# (6257, 23)

# %%
impaye
# Out:
#                             ZIBZIN  IDAvisAutorisAtionCheque  MontAnt  \
# 49       A075004265908008772124369                  71051662    45.07
# 245      A026010096908801944136301                  71077583    50.01
# 321      A012010003908132050370361                  71077780   211.14
# 473      A075002135908004172315358                  71078249     4.34
# 1496     A045010041908062118821033                  71081166    15.30
# ...                            ...                       ...      ...
# 2231066  A038010002908260082985326                  76191853    36.89
# 2231102  A075008315908204350454253                  76191923   183.40
# 2231258  A013010096908829320871101                  76192205   242.98
# 2231275  A006019106908043610265597                  76192241   134.47
# 2231320  A087010041908008749420027                  76192329    23.43
#
#              DAteTrAnsAction  CodeDecision  VerifiAnceCPT1  VerifiAnceCPT2  \
# ...

# %%
impaye.describe(include='all')
# Out:
#                            ZIBZIN  IDAvisAutorisAtionCheque      MontAnt  \
# count                        6257              6.257000e+03  6257.000000
# unique                       4069                       NaN          NaN
# top     A013010041908020729891229                       NaN          NaN
# freq                           14                       NaN          NaN
# mean                          NaN              7.372501e+07    94.557721
# std                           NaN              1.461851e+06   133.659270
# min                           NaN              7.105166e+07     3.170000
# 25%                           NaN              7.249057e+07    31.160000
# 50%                           NaN              7.379739e+07    50.630000
# 75%                           NaN              7.498143e+07   103.240000
# max                           NaN              7.619233e+07  3825.610000
#
#             DAteTrAnsAction  CodeDecision  VerifiAnceCPT1  VerifiAnceCPT2  \
# ...
